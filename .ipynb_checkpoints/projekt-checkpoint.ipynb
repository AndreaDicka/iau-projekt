# %% [markdown]
# # Prieskumná analýza datasetu č.17
#
# Autori: Andrea Dická a Ján Nemčík
# Cvičenie: Piatok, 8:00

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data = pd.read_csv("17/test.csv")
data.head()
# Out:
#    Unnamed: 0  age sex query on thyroxine on antithyroid medication  \
# 0           0   24   M                  f                         f
# 1           1   69   F                  f                         f
# 2           2   37   M                  f                         f
# 3           3   46   M                  f                         f
# 4           4   29   F                  f                         f
#
#   thyroid surgery I131 treatment tumor hypopituitary   TSH  \
# 0               f              f     f             f  3.30
# 1               f              f     f             f  1.10
# 2               f              f     f             f  2.60
# 3               f              f     f             f  0.25
# 4               f              f     f             f  1.60
#
#                          ...                               marital-status  \
# 0                        ...                           Married-civ-spouse
# ...

# %% [markdown]
# Hneď sme si všimli, že prvý stĺpec je nepomenovaný a vyjadruje iba číslo riadku, takže sme sa rozhodli, že je nepotrebný.

# %%
data = pd.read_csv("17/test.csv", sep=',', header=None, index_col=0)
data.head()
# Out:
#        1    2                   3                          4   \
# 0
# NaN   age  sex  query on thyroxine  on antithyroid medication
#  0.0   24    M                   f                          f
#  1.0   69    F                   f                          f
#  2.0   37    M                   f                          f
#  3.0   46    M                   f                          f
#
#                    5               6      7              8     9   \
# 0
# NaN   thyroid surgery  I131 treatment  tumor  hypopituitary   TSH
#  0.0                f               f      f              f   3.3
#  1.0                f               f      f              f   1.1
#  2.0                f               f      f              f   2.6
#  3.0                f               f      f              f  0.25
#
#                10                        ...                          \
# 0                                        ...
# NaN   T3 measured                        ...
# ...

# %%
data.columns = ["{:02d}".format(i) for i in range(len(data.columns))]
data.head()
# Out:
#        00   01                  02                         03  \
# 0
# NaN   age  sex  query on thyroxine  on antithyroid medication
#  0.0   24    M                   f                          f
#  1.0   69    F                   f                          f
#  2.0   37    M                   f                          f
#  3.0   46    M                   f                          f
#
#                    04              05     06             07    08  \
# 0
# NaN   thyroid surgery  I131 treatment  tumor  hypopituitary   TSH
#  0.0                f               f      f              f   3.3
#  1.0                f               f      f              f   1.1
#  2.0                f               f      f              f   2.6
#  3.0                f               f      f              f  0.25
#
#                09                        ...                          \
# 0                                        ...
# NaN   T3 measured                        ...
# ...

# %%
data.count()
# Out:
# 00    973
# 01    973
# 02    973
# 03    973
# 04    973
# 05    973
# 06    973
# 07    973
# 08    888
# 09    973
# 10    789
# 11    973
# 12    926
# 13    883
# 14    973
# 15    973
# 16    973
# 17    973
# 18    973
# 19    973
# 20    973
# 21    973
# 22    973
# 23    834
# 24    973
# 25    973
# 26    973
# 27    973
# 28    973
# 29    973
# 30    973
# 31    973
# 32    973
# 33    973
# dtype: int64

# %% [markdown]
# Vidíme, že máme k dispozícii 973 záznamov. Väčšina stĺpcov obsahuje všetky dáta, iba v piatich stĺpcoch sú nejaké chýbajúce dáta.

# %%
data = data.drop(data.columns[2:8], axis = 1)
data.head()
# Out:
#        00   01    08           09   10            11     12    13  \
# 0
# NaN   age  sex   TSH  T3 measured   T3  TT4 measured    TT4   T4U
#  0.0   24    M   3.3            t  1.2             t   70.0  0.87
#  1.0   69    F   1.1            t  1.9             t  135.0  0.96
#  2.0   37    M   2.6            t  2.3             t   68.0  0.94
#  3.0   46    M  0.25            t  2.0             t  112.0  1.01
#
#                 14   15                        ...                          \
# 0                                              ...
# NaN   FTI measured  FTI                        ...
#  0.0             t   80                        ...
#  1.0             t  141                        ...
#  2.0             t   72                        ...
#  3.0             t  111                        ...
#
#                        24                 25              26      27  \
# 0
# NaN        marital-status         occupation    relationship    race
# ...

# %%
data = data.drop(data.column['TBG'], axis = 1)
data.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-fcca58ca2011> in <module>()
# ----> 1 data = data.drop(data.column['TBG'], axis = 1)
#       2 data.head()
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'column'
